# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\saket\\Downloads\\edyoda data\\time_series_covid19_confirmed_global.csv")

# %%
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20   ...     3/14/20  3/15/20  3/16/20  3/17/20  \
# 0        0        0        0   ...          11       16       21       22
# 1        0        0        0   ...          38       42       51       55
# 2        0        0        0   ...          37       48       54       60
# 3        0        0        0   ...           1        1        2       39
# 4        0        0        0   ...           0        0        0        0
#
#    3/18/20  3/19/20  3/20/20  3/21/20  3/22/20  3/23/20
# ...

# %%
data.sample(10)
# Out:
#          Province/State       Country/Region      Lat      Long  1/22/20  \
# 60                Henan                China  33.8820  113.6140        5
# 168        Sint Maarten          Netherlands  18.0425  -63.0548        0
# 164                 NaN              Namibia -22.9576   18.4904        0
# 10   Northern Territory            Australia -12.4634  130.8456        0
# 21                  NaN             Barbados  13.1939  -59.5432        0
# 92        Faroe Islands              Denmark  61.8926   -6.9118        0
# 154                 NaN             Maldives   3.2028   73.2207        0
# 5                   NaN  Antigua and Barbuda  17.0608  -61.7964        0
# 83                  NaN  Congo (Brazzaville)  -4.0383   21.7587        0
# 219     Channel Islands       United Kingdom  49.3723   -2.3644        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20   ...     3/14/20  3/15/20  \
# 60         5        9       32       83      128   ...        1273     1273
# ...

# %% [markdown]
# ### what is the datat all about

# %% [markdown]
# ###
# * time is the column ,every day new column is added
# * a country can be reoresented into multiple state/province

# %% [markdown]
# * question : transform the data country specific

# %%
data['Country/Region'].value_counts()
# Out:
# China                   33
# Canada                  12
# France                  10
# Australia                8
# United Kingdom           7
# Netherlands              4
# Denmark                  3
# Guatemala                1
# Cabo Verde               1
# Paraguay                 1
# Somalia                  1
# US                       1
# Cyprus                   1
# Belgium                  1
# Switzerland              1
# Tanzania                 1
# Bahrain                  1
# Suriname                 1
# Korea, South             1
# Guinea                   1
# United Arab Emirates     1
# Kenya                    1
# Algeria                  1
# New Zealand              1
# Andorra                  1
# Grenada                  1
# Zimbabwe                 1
# Sudan                    1
# Cuba                     1
# Kyrgyzstan               1
#                         ..
# Belize                   1
# Poland                   1
# Venezuela                1
# ...

# %%
data = data.drop(['Lat','Long'],axis = 1)

# %%
country_data = data.groupby(['Country/Region'],axis = 0).sum()

# %%
country_data
# Out:
#                         1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                   0        0        0        0        0        0
# Albania                       0        0        0        0        0        0
# Algeria                       0        0        0        0        0        0
# Andorra                       0        0        0        0        0        0
# Angola                        0        0        0        0        0        0
# Antigua and Barbuda           0        0        0        0        0        0
# Argentina                     0        0        0        0        0        0
# Armenia                       0        0        0        0        0        0
# Australia                     0        0        0        0        4        5
# Austria                       0        0        0        0        0        0
# Azerbaijan                    0        0        0        0        0        0
# ...

# %%
country_data = country_data.T

# %%
country_data.columns
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'Uruguay', 'Uzbekistan', 'Venezuela', 'Vietnam', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country/Region', length=168)

# %%
country_data.index = pd.to_datetime(country_data.index)

# %%
country_data.head(2)
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 2020-01-22                0        0        0        0       0
# 2020-01-23                0        0        0        0       0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 2020-01-22                        0          0        0          0        0
# 2020-01-23                        0          0        0          0        0
#
# Country/Region    ...     Uganda  Ukraine  United Arab Emirates  \
# 2020-01-22        ...          0        0                     0
# 2020-01-23        ...          0        0                     0
#
# Country/Region  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# 2020-01-22                   0        0           0          0        0
# 2020-01-23                   0        0           0          0        2
#
# Country/Region  Zambia  Zimbabwe
# 2020-01-22           0         0
# 2020-01-23           0         0
#
# ...

# %%
country_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 62 entries, 2020-01-22 to 2020-03-23
# Columns: 168 entries, Afghanistan to Zimbabwe
# dtypes: int64(168)
# memory usage: 81.9 KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
country_data[['India','China','Italy','Iran']].plot()

# %%
top5 = list(country_data.loc['2020-03-23'].sort_values(ascending = False)[:6].index.values)

# %% [markdown]
# ### * status of countries leading the chart

# %%
country_data[top5].plot()

# %% [markdown]
# * stateus of USA

# %%
country_data.US.plot()

# %%
country_data.China.plot()

# %%
country_data.India.plot()

# %%
country_data[['China','US','India','Italy']].plot()

# %%
country_data.Italy.plot()

# %%
country_data.Pakistan.plot()

# %%
country_data[['India','Pakistan',"Egypt"]].plot()

# %%
death_data = pd.read_csv("C:\\Users\\saket\\Downloads\\edyoda data\\time_series_covid19_deaths_global.csv")

# %%
death_data = death_data.groupby('Country/Region',axis = 0).sum()

# %%
death_data = death_data.drop(['Lat','Long'],axis = 1)

# %%
death_data = death_data.T

# %%
death_data.index = pd.to_datetime(death_data.index)

# %%
death_data
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 2020-01-22                0        0        0        0       0
# 2020-01-23                0        0        0        0       0
# 2020-01-24                0        0        0        0       0
# 2020-01-25                0        0        0        0       0
# 2020-01-26                0        0        0        0       0
# 2020-01-27                0        0        0        0       0
# 2020-01-28                0        0        0        0       0
# 2020-01-29                0        0        0        0       0
# 2020-01-30                0        0        0        0       0
# 2020-01-31                0        0        0        0       0
# 2020-02-01                0        0        0        0       0
# 2020-02-02                0        0        0        0       0
# 2020-02-03                0        0        0        0       0
# 2020-02-04                0        0        0        0       0
# ...

# %%
death_data[top5].plot()

# %% [markdown]
# ### * which country is doing more testing and taking better care of people

# %%
res = death_data.loc['2020-03-23']/country_data.loc['2020-03-23']

# %%
res.sort_values(ascending=False)
# Out:
# Country/Region
# Sudan                  0.500000
# Gambia                 0.500000
# Zimbabwe               0.333333
# Gabon                  0.200000
# San Marino             0.106952
# Italy                  0.095062
# Bangladesh             0.090909
# Iraq                   0.086466
# Indonesia              0.084629
# Iran                   0.078615
# Ghana                  0.074074
# Algeria                0.073913
# Philippines            0.071429
# Spain                  0.065773
# Mauritius              0.055556
# Jamaica                0.052632
# Egypt                  0.051913
# Guatemala              0.050000
# Guyana                 0.050000
# United Kingdom         0.049955
# Paraguay               0.045455
# Netherlands            0.044920
# France                 0.042837
# Hungary                0.041916
# Ukraine                0.041096
# Burkina Faso           0.040404
# China                  0.040173
# Albania                0.038462
# ...

# %%
death_data.loc['2020-03-23'].Sudan
# Out:
# 1

# %%
country_data.loc['2020-03-23'].Sudan
# Out:
# 2

# %%
res_above50 = country_data.loc['2020-03-23'] > 50

# %%
res_above50[res_above50 == True].index
# Out:
# Index(['Albania', 'Algeria', 'Andorra', 'Argentina', 'Armenia', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahrain', 'Belarus', 'Belgium',
#        'Bosnia and Herzegovina', 'Brazil', 'Brunei', 'Bulgaria',
#        'Burkina Faso', 'Cambodia', 'Cameroon', 'Canada', 'Chile', 'China',
#        'Colombia', 'Costa Rica', 'Croatia', 'Cruise Ship', 'Cyprus', 'Czechia',
#        'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'Estonia',
#        'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel',
#        'Italy', 'Japan', 'Jordan', 'Kazakhstan', 'Korea, South', 'Kuwait',
#        'Latvia', 'Lebanon', 'Liechtenstein', 'Lithuania', 'Luxembourg',
#        'Malaysia', 'Malta', 'Mexico', 'Moldova', 'Morocco', 'Netherlands',
#        'New Zealand', 'North Macedonia', 'Norway', 'Oman', 'Pakistan',
#        'Panama', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Qatar',
# ...

# %%
deaths = death_data.loc['2020-03-23']

# %%
res_above50_deaths = deaths[res_above50[res_above50 == True].index]

# %%
affected = country_data.loc['2020-03-23']

# %%
res_above50_data = affected[res_above50[res_above50 == True].index]

# %%
res_above50_data
# Out:
# Country/Region
# Albania                     104
# Algeria                     230
# Andorra                     133
# Argentina                   301
# Armenia                     235
# Australia                  1682
# Austria                    4474
# Azerbaijan                   72
# Bahrain                     377
# Belarus                      81
# Belgium                    3743
# Bosnia and Herzegovina      136
# Brazil                     1924
# Brunei                       91
# Bulgaria                    201
# Burkina Faso                 99
# Cambodia                     87
# Cameroon                     56
# Canada                     2088
# Chile                       746
# China                     81498
# Colombia                    277
# Costa Rica                  158
# Croatia                     315
# Cruise Ship                 712
# Cyprus                      116
# Czechia                    1236
# Denmark                    1572
# ...

# %%
res_above50_deaths
# Out:
# Country/Region
# Albania                      4
# Algeria                     17
# Andorra                      1
# Argentina                    4
# Armenia                      0
# Australia                    7
# Austria                     21
# Azerbaijan                   1
# Bahrain                      2
# Belarus                      0
# Belgium                     88
# Bosnia and Herzegovina       1
# Brazil                      34
# Brunei                       0
# Bulgaria                     3
# Burkina Faso                 4
# Cambodia                     0
# Cameroon                     0
# Canada                      25
# Chile                        2
# China                     3274
# Colombia                     3
# Costa Rica                   2
# Croatia                      1
# Cruise Ship                  8
# Cyprus                       1
# Czechia                      1
# Denmark                     24
# Dominican Republic           3
# ...

# %%
final = res_above50_deaths / res_above50_data

# %%
final.sort_values(ascending=False)
# Out:
# Country/Region
# San Marino             0.106952
# Italy                  0.095062
# Iraq                   0.086466
# Indonesia              0.084629
# Iran                   0.078615
# Algeria                0.073913
# Philippines            0.071429
# Spain                  0.065773
# Egypt                  0.051913
# United Kingdom         0.049955
# Netherlands            0.044920
# France                 0.042837
# Hungary                0.041916
# Ukraine                0.041096
# Burkina Faso           0.040404
# China                  0.040173
# Albania                0.038462
# Japan                  0.037234
# Tunisia                0.033708
# Morocco                0.027972
# Greece                 0.024460
# Turkey                 0.024199
# Belgium                0.023511
# India                  0.020040
# Ecuador                0.018349
# Brazil                 0.017672
# Panama                 0.017391
# Denmark                0.015267
# ...

# %%
final['China']
# Out:
# 0.04017276497582763
