# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set(color_codes=True)
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 10]

# %%
import pandas_profiling
from pandas_profiling import ProfileReport

# %% [markdown]
# ### Objectives
# * Data Analysis
# * Building model for prediction
# * Hyper-Parameter-Tuning
# * Deployment Basics

# %%
data = pd.read_excel("C:\\Users\\saket\\Downloads\default of credit card clients.xls")

# %%
data.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
#         X21       X22       X23                           Y
# 0  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 1         0         0         0                           1
# 2      1000         0      2000                           1
# 3      1000      1000      5000                           0
# 4      1100      1069      1000                           0
#
# [5 rows x 25 columns]

# %%
columns = list(data.loc[0].values)

# %%
data = data[1:]

# %%
data.columns= columns

# %%
data.index = data.ID

# %%
data.head()
# Out:
#    ID LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  ...  \
# ID                                                                  ...
# 1   1     20000   2         2        1  24     2     2    -1    -1  ...
# 2   2    120000   2         2        2  26    -1     2     0     0  ...
# 3   3     90000   2         2        2  34     0     0     0     0  ...
# 4   4     50000   2         2        1  37     0     0     0     0  ...
# 5   5     50000   1         2        1  57    -1     0    -1     0  ...
#
#    BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4 PAY_AMT5  \
# ID
# 1          0         0         0        0      689        0        0        0
# 2       3272      3455      3261        0     1000     1000     1000        0
# 3      14331     14948     15549     1518     1500     1000     1000     1000
# 4      28314     28959     29547     2000     2019     1200     1100     1069
# 5      20940     19146     19131     2000    36681    10000     9000      689
#
#    PAY_AMT6 default payment next month
# ID
# 1         0                          1
# 2      2000                          1
# 3      5000                          0
# 4      1000                          0
# 5       679                          0
#
# [5 rows x 25 columns]

# %%
data.drop(columns=['ID'], inplace=True)

# %%
data.sample(10)
# Out:
#       LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4 PAY_5  ...  \
# ID                                                                        ...
# 24831     20000   1         3        2  43     0     0     0     0     0  ...
# 20241     90000   2         2        1  55    -2    -2    -2    -2    -2  ...
# 19601    200000   2         1        2  32    -2    -2    -2    -2    -2  ...
# 10254    220000   2         1        2  36    -1    -1    -1    -1    -1  ...
# 3288      30000   2         1        1  30     2     2     2     3     2  ...
# 28947    500000   2         1        1  37    -1    -1    -1    -1    -1  ...
# 20479     30000   1         2        2  28     2     0     0     0     0  ...
# 12679     50000   1         2        1  48     2     0     0     0     0  ...
# 18164    200000   1         1        1  46     0     0     0     0     0  ...
# 24313    260000   1         2        1  32    -1     0     0     0     0  ...
#
#       BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4  \
# ID
# 24831     17891     18590     19286     2000     1271     3000     1000
# 20241         0         0      7707        0        0        0        0
# 19601         0         0      2820        0     2090        0        0
# 10254      3750       657         0     1734      827     3750        0
# 3288      13394     13036     15019     1300     1500        0        0
# 28947      1587     61385     56252    17470    15091     1587    61385
# 20479     27107     27450     29193     1800     1500     1600     1000
# 12679     19424     19829     20386     2077     1311      689      712
# 18164     55712     56421     57203     1765     1828     1811     1816
# 24313     19623     20012     20466     5000     5000     5000      716
#
#       PAY_AMT5 PAY_AMT6 default payment next month
# ID
# 24831     1000     1000                          0
# 20241     7707        0                          0
# 19601     2820    10540                          0
# 10254        0        0                          0
# 3288      2200        0                          1
# 28947        0    56733                          1
# 20479     2100     1400                          0
# 12679      879      799                          0
# 18164     1880     4123                          0
# 24313      776     5000                          0
#
# [10 rows x 24 columns]

# %%
profile = ProfileReport(data,title = 'Defaulter_Prediction',explorative= True)

# %%
data.shape
# Out:
# (30000, 24)

# %%
#profile.to_file("defaulters")

# %%
#profile.to_file("defaulters")

# %%
#file:///C:/Users/saket/Downloads/jupyter notebook/DS _REV/defaulters.html

# %% [markdown]
# ### Prediction Objective
# * we want to predict from this data if a person will default next month or not

# %%
data.rename(columns={'default payment next month':'def_next_month'}, inplace=True)

# %%
data.sample(5)
# Out:
#       LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4 PAY_5  ...  \
# ID                                                                        ...
# 15106    180000   1         1        2  36    -2    -2    -2    -2    -1  ...
# 9322     500000   2         1        2  34     0     0     0     0     0  ...
# 12262    270000   2         1        1  40    -1    -1    -1    -1    -1  ...
# 21947    340000   2         3        2  28     0     0     0     0     0  ...
# 10583     80000   2         3        2  54     0     0     0    -1    -1  ...
#
#       BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4  \
# ID
# 15106         0       680     34704        0        0        0      680
# 9322     262663    308074    400050    26000    20000   106700    50000
# 12262     29677     33341     28413    34813    43856    29682    33341
# 21947     12519     15299     15905     3000     3000     5000     3000
# 10583      4000         0      4000     3794     6000     6500        0
#
#       PAY_AMT5 PAY_AMT6 def_next_month
# ID
# 15106    34704      700              0
# 9322    100000   200000              0
# 12262    28413     1351              0
# 21947     1000    10000              0
# 10583     4000        0              0
#
# [5 rows x 24 columns]

# %%
data.def_next_month.value_counts()
# Out:
# 0    23364
# 1     6636
# Name: def_next_month, dtype: int64

# %% [markdown]
# ### Observation about target columns:
# * The data contains Imbalanced classes

# %%
payment_status = data.filter(regex='PAY_\d')

# %%
payment_status
# Out:
#       PAY_0 PAY_2 PAY_3 PAY_4 PAY_5 PAY_6
# ID
# 1         2     2    -1    -1    -2    -2
# 2        -1     2     0     0     0     2
# 3         0     0     0     0     0     0
# 4         0     0     0     0     0     0
# 5        -1     0    -1     0     0     0
# ...     ...   ...   ...   ...   ...   ...
# 29996     0     0     0     0     0     0
# 29997    -1    -1    -1    -1     0     0
# 29998     4     3     2    -1     0     0
# 29999     1    -1     0     0     0    -1
# 30000     0     0     0     0     0     0
#
# [30000 rows x 6 columns]

# %%
payment_status.PAY_0.value_counts()
# Out:
#  0    14737
# -1     5686
#  1     3688
# -2     2759
#  2     2667
#  3      322
#  4       76
#  5       26
#  8       19
#  6       11
#  7        9
# Name: PAY_0, dtype: int64

# %% [markdown]
# ### In columns PAY_0..5 0/-1/-2 represents payments done
# * Putting them all in the same bucket,Marking them to 0 since they have paid
# * -1,-2 means paid in advance

# %%
cols = list(payment_status.columns)

# %%
for col in cols:
    data[col] = data[col].map(lambda v:0 if v<0 else v)

# %%
data.sample(5)
# Out:
#       LIMIT_BAL SEX EDUCATION MARRIAGE AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# ID
# 29956    410000   1         1        2  32      0      2      0      0      0
# 2525      20000   1         2        2  23      0      0      0      0      0
# 14911    310000   2         1        2  27      0      0      0      0      0
# 15398     50000   2         3        1  55      0      0      0      0      0
# 18278    180000   1         3        1  58      2      2      2      2      2
#
#        ...  BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4  \
# ID     ...
# 29956  ...        380       190      1539        0      190      380        0
# 2525   ...      12596     11699      2154     1011    13181        5     1033
# 14911  ...      93929     87681     73479     5222     5197     4000     5000
# 15398  ...      12423     41956     45112     1831     1189     3467    30000
# 18278  ...      38808     39474     40297     2000        0     3405     1600
#
#       PAY_AMT5 PAY_AMT6 def_next_month
# ID
# 29956     1539        0              0
# 2525      1781      305              0
# 14911     3980     3271              0
# 15398     4000        0              0
# 18278     1600     1700              1
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Baselining Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
for col in data.columns:
    data[col] = data[col].astype('int64')

# %%
trainX, testX, trainY, testY = train_test_split(data.drop(columns=['def_next_month']), data.def_next_month)

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(trainX,trainY)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(testX,testY)
# Out:
# 0.728

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = dt.predict(testX)

# %%
confusion_matrix(y_pred=y_pred,y_true=testY)
# Out:
# array([[4775, 1055],
#        [ 985,  685]], dtype=int64)

# %%
pd.DataFrame(confusion_matrix(y_pred=y_pred, y_true=testY), columns=['Predicted 0', 'Predicted 1'], index=['Actual 0', 'Actual 1'])
# Out:
#           Predicted 0  Predicted 1
# Actual 0         4775         1055
# Actual 1          985          685

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %%
smote = SMOTE()

# %%
feature_s, target_s = smote.fit_sample(data.drop(columns=['def_next_month']), data.def_next_month)

# %%
trainX, testX, trainY, testY = train_test_split(feature_s, target_s)

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(trainX, trainY)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(testX)

# %%
pd.DataFrame(confusion_matrix(y_pred=y_pred, y_true=testY), columns=['Predicted 0', 'Predicted 1'], index=['Actual 0', 'Actual 1'])
# Out:
#           Predicted 0  Predicted 1
# Actual 0         4251         1608
# Actual 1         1393         4430

# %%
dt.score(testX, testY)
# Out:
# 0.7431090566683787

# %% [markdown]
# ### Improving further¶

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, n_jobs=3)

# %%
rf.fit(trainX, trainY)
# Out:
# RandomForestClassifier(n_jobs=3)

# %%
y_pred = rf.predict(testX)

# %%
pd.DataFrame(confusion_matrix(y_pred=y_pred, y_true=testY), columns=['Predicted 0', 'Predicted 1'], index=['Actual 0', 'Actual 1'])
# Out:
#           Predicted 0  Predicted 1
# Actual 0         5056          803
# Actual 1         1101         4722

# %%
feature_cols = list(data.drop(columns=['def_next_month']).columns)

# %%
feature_imp = pd.Series(rf.feature_importances_, index= feature_cols)

# %%
top_features = list(feature_imp.sort_values(ascending=False)[:-5].index)

# %%
top_features
# Out:
# ['PAY_0',
#  'LIMIT_BAL',
#  'BILL_AMT1',
#  'AGE',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'BILL_AMT2',
#  'PAY_AMT3',
#  'PAY_2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'PAY_AMT4',
#  'BILL_AMT5',
#  'PAY_AMT6',
#  'BILL_AMT6',
#  'PAY_AMT5',
#  'MARRIAGE',
#  'SEX']

# %%
feature_s, target_s = smote.fit_sample(data[top_features], data.def_next_month)

# %%
rf = RandomForestClassifier(n_estimators=1000, n_jobs=3)

# %%
rf.fit(trainX, trainY)
# Out:
# RandomForestClassifier(n_estimators=1000, n_jobs=3)

# %%
rf.score(testX,testY)
# Out:
# 0.8394966615305598

# %%
y_pred = rf.predict(testX)

# %%
pd.DataFrame(confusion_matrix(y_pred=y_pred, y_true=testY), columns=['Predicted 0', 'Predicted 1'], index=['Actual 0', 'Actual 1'])
# Out:
#           Predicted 0  Predicted 1
# Actual 0         5052          807
# Actual 1         1068         4755
