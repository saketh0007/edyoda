# %%
import pandas as pd

# %% [markdown]
# ### 14-07-2020

# %% [markdown]
# ### two data structures in data frames

# %% [markdown]
# * series
# * Dataframes

# %%
s1 = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])

# %%
s2 = pd.Series([11,12,13,14,15],index = ['a','b','c','d','e'] )

# %%
df = pd.DataFrame({'C1':s1, 'C2':s2})

# %%
df
# Out:
#    C1  C2
# a   1  11
# b   2  12
# c   3  13
# d   4  14
# e   5  15

# %%
hr_df = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt')

# %% [markdown]
# ### Descreptive Analysis

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Extract subset based on tyype

# %%
hr_df.select_dtypes(include=['int64']).head()
# Out:
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0               2                   157                   3              0
# 1               5                   262                   6              0
# 2               7                   272                   4              0
# 3               5                   223                   5              0
# 4               2                   159                   3              0
#
#    left  promotion_last_5years
# 0     1                      0
# 1     1                      0
# 2     1                      0
# 3     1                      0
# 4     1                      0

# %%
hr_df.select_dtypes(include=[object]).head()
# Out:
#    sales  salary
# 0  sales     low
# 1  sales  medium
# 2  sales  medium
# 3  sales     low
# 4  sales     low

# %% [markdown]
# ### select subset of columns

# %%
type(hr_df.salary)
# Out:
# pandas.core.series.Series

# %%
hr_df[['salary','left']].head()
# Out:
#    salary  left
# 0     low     1
# 1  medium     1
# 2  medium     1
# 3     low     1
# 4     low     1

# %% [markdown]
# ### Describing the data

# %%
hr_df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
hr_df.satisfaction_level.unique()
# Out:
# array([0.38, 0.8 , 0.11, 0.72, 0.37, 0.41, 0.1 , 0.92, 0.89, 0.42, 0.45,
#        0.84, 0.36, 0.78, 0.76, 0.09, 0.46, 0.4 , 0.82, 0.87, 0.57, 0.43,
#        0.13, 0.44, 0.39, 0.85, 0.81, 0.9 , 0.74, 0.79, 0.17, 0.24, 0.91,
#        0.71, 0.86, 0.14, 0.75, 0.7 , 0.31, 0.73, 0.83, 0.32, 0.54, 0.27,
#        0.77, 0.88, 0.48, 0.19, 0.6 , 0.12, 0.61, 0.33, 0.56, 0.47, 0.28,
#        0.55, 0.53, 0.59, 0.66, 0.25, 0.34, 0.58, 0.51, 0.35, 0.64, 0.5 ,
#        0.23, 0.15, 0.49, 0.3 , 0.63, 0.21, 0.62, 0.29, 0.2 , 0.16, 0.65,
#        0.68, 0.67, 0.22, 0.26, 0.99, 0.98, 1.  , 0.52, 0.93, 0.97, 0.69,
#        0.94, 0.96, 0.18, 0.95])

# %%
hr_df.sales.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_df.rename(columns={'sales':'department'},inplace = True)

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
hr_df.department.value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %% [markdown]
# ### saving changed data files

# %% [raw]
# hr_df.to_csv('~corrected_data.csv')

# %% [markdown]
# ### identifying Missing values

# %%
titanic_df = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/titanic-train.csv.txt', index_col='PassengerId')

# %%
titanic_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 66.1+ KB

# %%
titanic_df[titanic_df.Age.isnull()]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 18                  1       2              Williams, Mr. Charles Eugene
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
titanic_df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ## Pandas 2

# %% [markdown]
# ### Topics
# * changing column names
# * Filtering
# * Accessing rows
# * Data Transformation

# %%
import pandas as pd

# %%
hr_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/HR_comma_sep.csv.txt')

# %%
hr_data.sales.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_data.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %% [markdown]
# ### Renaming a column

# %%
hr_data.rename(columns={'sales':'department'},inplace = True)

# %% [markdown]
# ### Find People with low salary

# %%
hr_data[hr_data.salary == 'low'].head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
# 5                   3              0     1                      0      sales
# 6                   4              0     1                      0      sales
#
#   salary
# 0    low
# 3    low
# ...

# %%
hr_data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
hr_data[hr_data.average_montly_hours > 245].head()
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 1                 0.80             0.86               5                   262
# 2                 0.11             0.88               7                   272
# 6                 0.10             0.77               6                   247
# 7                 0.92             0.85               5                   259
# 11                0.11             0.81               6                   305
#
#     time_spend_company  Work_accident  left  promotion_last_5years department  \
# 1                    6              0     1                      0      sales
# 2                    4              0     1                      0      sales
# 6                    4              0     1                      0      sales
# 7                    5              0     1                      0      sales
# 11                   4              0     1                      0      sales
#
#     salary
# 1   medium
# ...

# %%
hr_data[hr_data.average_montly_hours > 245 & (hr_data.salary == "low")].head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# * find satisfied people who are still working with low salary

# %%
hr_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
hr_data[(hr_data.satisfaction_level > 0.82) & (hr_data.left == 0) & (hr_data.salary == 'low')].head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 2007                0.99             0.91               5
# 2023                1.00             0.41               4
# 2029                0.84             0.77               4
# 2030                0.85             0.59               3
# 2041                0.98             0.91               4
#
#       average_montly_hours  time_spend_company  Work_accident  left  \
# 2007                   136                   4              0     0
# 2023                   174                   3              0     0
# 2029                   262                   4              0     0
# 2030                   235                   3              0     0
# 2041                   240                   3              0     0
#
#       promotion_last_5years department salary
# 2007                      0      sales    low
# 2023                      0  technical    low
# 2029                      0  technical    low
# ...

# %%
hr_data[5:10][['satisfaction_level','number_project']]
# Out:
#    satisfaction_level  number_project
# 5                0.41               2
# 6                0.10               6
# 7                0.92               5
# 8                0.89               5
# 9                0.42               2

# %%
hr_data.iloc[[2,4,10]]
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 2                 0.11             0.88               7                   272
# 4                 0.37             0.52               2                   159
# 10                0.45             0.54               2                   135
#
#     time_spend_company  Work_accident  left  promotion_last_5years department  \
# 2                    4              0     1                      0      sales
# 4                    3              0     1                      0      sales
# 10                   3              0     1                      0      sales
#
#     salary
# 2   medium
# 4      low
# 10     low

# %% [markdown]
# * access all rows multiple of 5

# %%
hr_data[::5]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 5                    0.41             0.50               2
# 10                   0.45             0.54               2
# 15                   0.38             0.54               2
# 20                   0.11             0.83               6
# ...                   ...              ...             ...
# 14975                0.10             0.79               7
# 14980                0.76             0.89               5
# 14985                0.91             0.99               5
# 14990                0.89             0.88               5
# 14995                0.37             0.48               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 5                       153                   3              0     1
# ...

# %%
hr_data.iloc[[x for x in range (14000) if x % 5 == 0]].head()
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.38             0.53               2                   157
# 5                 0.41             0.50               2                   153
# 10                0.45             0.54               2                   135
# 15                0.38             0.54               2                   143
# 20                0.11             0.83               6                   282
#
#     time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                    3              0     1                      0      sales
# 5                    3              0     1                      0      sales
# 10                   3              0     1                      0      sales
# 15                   3              0     1                      0      sales
# 20                   4              0     1                      0      sales
#
#    salary
# 0     low
# ...

# %%
titanic_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/titanic-train.csv.txt', index_col='PassengerId')

# %%
titanic_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic_data.loc[2:5]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
titanic_data.iloc[2:5]
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket    Fare Cabin  \
# PassengerId
# 3            female  26.0      0      0  STON/O2. 3101282   7.925   NaN
# 4            female  35.0      1      0            113803  53.100  C123
# 5              male  35.0      0      0            373450   8.050   NaN
#
#             Embarked
# PassengerId
# 3                  S
# 4                  S
# 5                  S

# %% [markdown]
# ### Data transformation
# * changing the column
# * sales and marketing team will be mearged
# * rename the department column for sales and marketing to s&m

# %%
def f(d):
    if (d=='sales') | (d=='marketing'):
        return 'S&M'
    else:
        return d


hr_data['new dept'] = hr_data.department.map(f)

# %%
hr_data .sample(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 9926                 0.88             0.56               4
# 3083                 0.46             0.49               3
# 472                  0.89             0.85               5
# 2737                 0.63             0.50               3
# 10760                0.59             0.97               3
# 9072                 0.63             0.81               4
# 13859                0.17             0.66               6
# 3118                 0.50             0.77               3
# 2675                 0.87             0.90               4
# 6567                 0.30             0.97               3
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 9926                    243                   4              0     0
# 3083                    213                   3              0     0
# 472                     266                   5              0     1
# ...

# %%
def f(r):
    if (r.satisfaction_level > 0.82) & (r.left == 0) & (r.salary == 'low' ):
        return 'medium'
    else :
        return r.salary 



hr_data['New Salary'] = hr_data.apply(f,axis = 1)

# %%
hr_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary new dept New Salary
# ...

# %%
hr_data[hr_data.salary != hr_data['New Salary']].head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 2007                0.99             0.91               5
# 2023                1.00             0.41               4
# 2029                0.84             0.77               4
# 2030                0.85             0.59               3
# 2041                0.98             0.91               4
#
#       average_montly_hours  time_spend_company  Work_accident  left  \
# 2007                   136                   4              0     0
# 2023                   174                   3              0     0
# 2029                   262                   4              0     0
# 2030                   235                   3              0     0
# 2041                   240                   3              0     0
#
#       promotion_last_5years department salary   new dept New Salary
# 2007                      0      sales    low        S&M     medium
# 2023                      0  technical    low  technical     medium
# ...

# %%
data = pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})

# %%
data
import numpy as np

# %%
def f(c):
    return np.sum(c)
data.apply(f,axis=1)
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %% [markdown]
# # pandas 3

# %% [markdown]
# * String data processing
# * handling missing values
# * structuring the data

# %%
horror_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/horror-train.csv')

# %%
horror_data.head()
# Out:
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL

# %%
horror_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19579 entries, 0 to 19578
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      19579 non-null  object
#  1   text    19579 non-null  object
#  2   author  19579 non-null  object
# dtypes: object(3)
# memory usage: 229.5+ KB

# %%
horror_data.author.unique()
# Out:
# array(['EAP', 'HPL', 'MWS'], dtype=object)

# %%
horror_data.author.value_counts()
# Out:
# EAP    7900
# MWS    6044
# HPL    5635
# Name: author, dtype: int64

# %% [markdown]
# * find out all the data of EAP

# %%
horror_data[horror_data.author == 'EAP']['text'][:5]
# Out:
# 0    This process, however, afforded me no means of...
# 2    In his left hand was a gold snuff box, from wh...
# 6    The astronomer, perhaps, at this point, took r...
# 7          The surcingle hung in ribands from my body.
# 8    I knew that you could not say to yourself 'ste...
# Name: text, dtype: object

# %%
horror_data['text_len'] = horror_data.text.str.len()

# %%
horror_data
# Out:
#             id                                               text author  \
# 0      id26305  This process, however, afforded me no means of...    EAP
# 1      id17569  It never once occurred to me that the fumbling...    HPL
# 2      id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3      id27763  How lovely is spring As we looked from Windsor...    MWS
# 4      id12958  Finding nothing else, not even gold, the Super...    HPL
# ...        ...                                                ...    ...
# 19574  id17718  I could have fancied, while I looked at it, th...    EAP
# 19575  id08973  The lids clenched themselves together as if in...    EAP
# 19576  id05267  Mais il faut agir that is to say, a Frenchman ...    EAP
# 19577  id17513  For an item of news like this, it strikes us i...    EAP
# 19578  id00393  He laid a gnarled claw on my shoulder, and it ...    HPL
#
#        text_len
# 0           231
# 1            71
# 2           200
# 3           206
# ...

# %% [markdown]
# find out the longest text

# %%
c= horror_data.text

# %%
c
# Out:
# 0        This process, however, afforded me no means of...
# 1        It never once occurred to me that the fumbling...
# 2        In his left hand was a gold snuff box, from wh...
# 3        How lovely is spring As we looked from Windsor...
# 4        Finding nothing else, not even gold, the Super...
#                                ...
# 19574    I could have fancied, while I looked at it, th...
# 19575    The lids clenched themselves together as if in...
# 19576    Mais il faut agir that is to say, a Frenchman ...
# 19577    For an item of news like this, it strikes us i...
# 19578    He laid a gnarled claw on my shoulder, and it ...
# Name: text, Length: 19579, dtype: object

# %%
c.str

# %%
horror_data.text_len.max()
# Out:
# 4663

# %%
horror_data[horror_data.text_len == 4663]
# Out:
#            id                                               text author  \
# 9215  id27184  Diotima approached the fountain seated herself...    MWS
#
#       text_len
# 9215      4663

# %% [markdown]
# * not optimized

# %%
max(horror_data.text_len)
# Out:
# 4663

# %% [markdown]
# filter the rows having hand in it

# %%
horror_data[horror_data.text.str.contains('hand')].head()
# Out:
#           id                                               text author  \
# 2    id11008  In his left hand was a gold snuff box, from wh...    EAP
# 22   id18925  On every hand was a wilderness of balconies, o...    EAP
# 23   id19925  With how deep a spirit of wonder and perplexit...    EAP
# 90   id03833  The ex queen gives me Idris; Adrian is totally...    MWS
# 147  id05876  I look on the hands which executed the deed; I...    MWS
#
#      text_len
# 2         200
# 22        115
# 23        460
# 90        130
# 147       224

# %% [markdown]
# * Find the row with maximum number of words

# %%
horror_data['list_words'] = horror_data.text.str.split()

# %%
horror_data.head()
# Out:
#         id                                               text author  \
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL
#
#    text_len                                         list_words
# 0       231  [This, process,, however,, afforded, me, no, m...
# 1        71  [It, never, once, occurred, to, me, that, the,...
# 2       200  [In, his, left, hand, was, a, gold, snuff, box...
# 3       206  [How, lovely, is, spring, As, we, looked, from...
# 4       174  [Finding, nothing, else,, not, even, gold,, th...

# %%
horror_data['num_words'] = horror_data.list_words.map(lambda r:len(r))

# %%
horror_data.num_words.max()
# Out:
# 861

# %%
horror_data[horror_data.num_words == 861]
# Out:
#            id                                               text author  \
# 9215  id27184  Diotima approached the fountain seated herself...    MWS
#
#       text_len                                         list_words  num_words
# 9215      4663  [Diotima, approached, the, fountain, seated, h...        861

# %% [markdown]
# ### Find the rows with maximum number of upper case words

# %%
def f(x):
    return len(list(filter(lambda w: w.istitle(),x)))
horror_data['title_words'] = horror_data.list_words.map(f)

# %%
horror_data.head()
# Out:
#         id                                               text author  \
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL
#
#    text_len                                         list_words  num_words  \
# 0       231  [This, process,, however,, afforded, me, no, m...         41
# 1        71  [It, never, once, occurred, to, me, that, the,...         14
# 2       200  [In, his, left, hand, was, a, gold, snuff, box...         36
# 3       206  [How, lovely, is, spring, As, we, looked, from...         34
# 4       174  [Finding, nothing, else,, not, even, gold,, th...         27
#
#    title_words
# 0            3
# 1            1
# 2            1
# 3            4
# 4            2

# %%
horror_data.title_words.max()
# Out:
# 46

# %%
horror_data[horror_data.title_words == 46]
# Out:
#            id                                               text author  \
# 9215  id27184  Diotima approached the fountain seated herself...    MWS
#
#       text_len                                         list_words  num_words  \
# 9215      4663  [Diotima, approached, the, fountain, seated, h...        861
#
#       title_words
# 9215           46

# %% [markdown]
# ### Handling missing values
# * two strtagies
#    - fill the missing values
#    - delete the rows

# %%
titanic_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/titanic-train.csv.txt')

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %% [markdown]
# #### Inference
# * Age,cabin,embarked has missing values

# %% [markdown]
# #### Q.Find all the rows in which age is missing¶

# %%
titanic_data[titanic_data.Age.isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %% [markdown]
# #### Q. Find all the rows in which Embarked is missing

# %%
titanic_data[titanic_data.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# ##### Q.Identify mean age of the people travelling in titanic

# %%
titanic_data.Age.mean()
# Out:
# 29.69911764705882

# %%
titanic_data.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ##### Q. Replace missing age by mean value, cabin & embarked¶

# %%
titanic_data.fillna({"Age":29.6,'Cabin':'NA','Embarked':'S'},inplace = True)

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    NA        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    NA        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    NA        S

# %%
titanic_d = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/titanic-train.csv.txt')

# %% [markdown]
# ##### Q. Drop the rows in which age is missing¶

# %%
titanic_d.dropna(subset=['Age']).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
titanic_d.dropna(inplace = True)

# %%
titanic_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 15.0+ KB

# %% [markdown]
# ### Understanding pivot table

# %%
gap_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/gapminder-FiveYearData.csv')

# %%
gap_data.sample(10)
# Out:
#        country  year          pop continent  lifeExp     gdpPercap
# 1628   Uruguay  1992    3149262.0  Americas   72.752   8137.004775
# 539     France  2007   61083916.0    Europe   80.657  30470.016700
# 499    Eritrea  1987    2915959.0    Africa   46.453    521.134133
# 172     Brazil  1972  100840058.0  Americas   59.504   4985.711467
# 373    Croatia  1957    3991242.0    Europe   64.770   4338.231617
# 1046   Myanmar  1962   23634436.0      Asia   45.108    388.000000
# 87     Bahrain  1967     202182.0      Asia   59.923  14804.672700
# 1701  Zimbabwe  1997   11404948.0    Africa   46.809    792.449960
# 1562   Tunisia  1962    4286552.0    Africa   49.579   1660.303210
# 1075     Nepal  1987   17917180.0      Asia   52.537    775.632450

# %%
life_exp_country = gap_data.pivot_table(index = 'country',columns = 'year',values = 'lifeExp')

# %%
life_exp_country.sample(10)
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Libya               42.723  45.289  47.808  50.227  52.773  57.442  62.155
# Paraguay            62.649  63.196  64.361  64.951  65.815  66.353  66.874
# Ecuador             48.357  51.356  54.640  56.678  58.796  61.310  64.342
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Hong Kong China     60.960  64.750  67.650  70.000  72.000  73.600  75.450
# Cambodia            39.417  41.366  43.415  45.415  40.317  31.220  50.957
# Netherlands         72.130  72.990  73.230  73.820  73.750  75.240  76.050
# Sweden              71.860  72.490  73.370  74.160  74.720  75.440  76.420
# Belgium             68.000  69.240  70.250  70.940  71.440  72.800  73.930
# Switzerland         69.620  70.560  71.320  72.770  73.780  75.390  76.210
#
# year                  1987    1992    1997    2002    2007
# country
# Libya               66.234  68.755  71.555  72.737  73.952
# ...

# %% [markdown]
# #### Find out most improved country in terms of life expectancy

# %%
life_exp_country['improvement'] = life_exp_country[2007] - life_exp_country[1952]

# %%
life_exp_country[life_exp_country.improvement == life_exp_country.improvement.max()]
# Out:
# year       1952   1957    1962    1967    1972    1977    1982    1987  \
# country
# Oman     37.578  40.08  43.165  46.988  52.143  57.367  62.728  67.734
#
# year       1992    1997    2002   2007  improvement
# country
# Oman     71.197  72.499  74.193  75.64       38.062

# %% [markdown]
# ### Calculate lifeExp of the continent as mean of all the countries belonging to it

# %%
gap_data.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %%
ggap_data = gap_data.groupby(['continent','year'])

# %%
result = ggap_data.lifeExp.mean()

# %%
result.sample(10)
# Out:
# continent  year
# Asia       1967    54.663640
#            1972    57.319269
#            1987    64.851182
# Europe     1972    70.775033
# Oceania    1992    76.945000
# Europe     2002    76.700600
# Oceania    1987    75.320000
# Americas   1997    71.150480
# Oceania    1972    71.910000
# Americas   1992    69.568360
# Name: lifeExp, dtype: float64

# %%
continent_lifeExp_data = pd.DataFrame(result)

# %%
continent_lifeExp_data.sample(10)
# Out:
#                   lifeExp
# continent year
# Europe    1997  75.505167
# Americas  1982  66.228840
# Oceania   1962  71.085000
#           1997  78.190000
# Europe    1962  68.539233
# Oceania   2002  79.740000
# Europe    1967  69.737600
# Americas  1962  58.398760
# Africa    1952  39.135500
# Europe    2002  76.700600

# %% [markdown]
# * Unstacking for converting inner index to column

# %%
continent_lifeExp_data.unstack()
# Out:
#              lifeExp                                                         \
# year            1952       1957       1962       1967       1972       1977
# continent
# Africa     39.135500  41.266346  43.319442  45.334538  47.450942  49.580423
# Americas   53.279840  55.960280  58.398760  60.410920  62.394920  64.391560
# Asia       46.314394  49.318544  51.563223  54.663640  57.319269  59.610556
# Europe     64.408500  66.703067  68.539233  69.737600  70.775033  71.937767
# Oceania    69.255000  70.295000  71.085000  71.310000  71.910000  72.855000
#
#
# year            1982       1987       1992       1997       2002       2007
# continent
# Africa     51.592865  53.344788  53.629577  53.598269  53.325231  54.806038
# Americas   66.228840  68.090720  69.568360  71.150480  72.422040  73.608120
# Asia       62.617939  64.851182  66.537212  68.020515  69.233879  70.728485
# Europe     72.806400  73.642167  74.440100  75.505167  76.700600  77.648600
# ...

# %%
import numpy as np

# %%
gap_data.pivot_table(index='continent',columns='year', values= 'lifeExp', aggfunc=np.mean )
# Out:
# year            1952       1957       1962       1967       1972       1977  \
# continent
# Africa     39.135500  41.266346  43.319442  45.334538  47.450942  49.580423
# Americas   53.279840  55.960280  58.398760  60.410920  62.394920  64.391560
# Asia       46.314394  49.318544  51.563223  54.663640  57.319269  59.610556
# Europe     64.408500  66.703067  68.539233  69.737600  70.775033  71.937767
# Oceania    69.255000  70.295000  71.085000  71.310000  71.910000  72.855000
#
# year            1982       1987       1992       1997       2002       2007
# continent
# Africa     51.592865  53.344788  53.629577  53.598269  53.325231  54.806038
# Americas   66.228840  68.090720  69.568360  71.150480  72.422040  73.608120
# Asia       62.617939  64.851182  66.537212  68.020515  69.233879  70.728485
# Europe     72.806400  73.642167  74.440100  75.505167  76.700600  77.648600
# Oceania    74.290000  75.320000  76.945000  78.190000  79.740000  80.719500
